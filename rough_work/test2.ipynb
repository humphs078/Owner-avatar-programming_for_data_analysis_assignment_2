# %%
# import the required software libraries
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt

# %%
co2 = pd.read_excel('/home/humphs01/Documents/ATU/programming_for_data_analysis_assignment_2/datasets/historic/grl52461-sup-0003-supplementary.xls', sheet_name="all records")

# %%
co2
# Out:
#           Dome C (0-22 kyr BP) Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0    Monnin et al. (2001+2004)        NaN        NaN        NaN        NaN
# 1                          NaN        NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN        NaN
# 3                          NaN        NaN        NaN        NaN        NaN
# 4           University of Bern        NaN        NaN        NaN        NaN
# ..                         ...        ...        ...        ...        ...
# 393                        NaN        NaN        NaN        NaN        NaN
# 394                        NaN        NaN        NaN        NaN        NaN
# 395                        NaN        NaN        NaN        NaN        NaN
# 396                        NaN        NaN        NaN        NaN        NaN
# 397                        NaN        NaN        NaN        NaN        NaN
#
#      Vostok (0-440 kyr BP) Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...

# %%
rubino = co2.iloc[6:, 83:85]

# %%
rubino
# Out:
#     Unnamed: 83 Unnamed: 84
# 6        -51.03  367.999993
# 7        -51.03  368.044983
# 8           -48  361.780737
# 9    -46.279272  359.619747
# 10   -46.279272  359.674988
# ..          ...         ...
# 393         NaN         NaN
# 394         NaN         NaN
# 395         NaN         NaN
# 396         NaN         NaN
# 397         NaN         NaN
#
# [392 rows x 2 columns]

# %%
rubino.rename(columns=({'Unnamed: 83':'yr_bp', 'Unnamed: 84':'co2_ppmv'}), inplace=True)

# %%
rubino
# Out:
#          yr_bp    co2_ppmv
# 6       -51.03  367.999993
# 7       -51.03  368.044983
# 8          -48  361.780737
# 9   -46.279272  359.619747
# 10  -46.279272  359.674988
# ..         ...         ...
# 393        NaN         NaN
# 394        NaN         NaN
# 395        NaN         NaN
# 396        NaN         NaN
# 397        NaN         NaN
#
# [392 rows x 2 columns]

# %%
# law_dome['year'] = 1950-(law_dome['yr_bp'])

# %%
# law_dome['years_before_present'] = 2023 - law_dome['year']

# %%
def year(sample):
    sample['year'] = 1950-(sample['yr_bp'])
    sample['years_before_present'] = 2023 - law_dome['year']
    return sample

# %%
year(rubino)
# Out:
#          yr_bp    co2_ppmv         year years_before_present
# 6       -51.03  367.999993      2001.03                 26.5
# 7       -51.03  368.044983      2001.03                 28.5
# 8          -48  361.780737         1998                 30.6
# 9   -46.279272  359.619747  1996.279272                 33.2
# 10  -46.279272  359.674988  1996.279272                 39.3
# ..         ...         ...          ...                  ...
# 393        NaN         NaN          NaN                  NaN
# 394        NaN         NaN          NaN                  NaN
# 395        NaN         NaN          NaN                  NaN
# 396        NaN         NaN          NaN                  NaN
# 397        NaN         NaN          NaN                  NaN
#
# [392 rows x 4 columns]

# %%
rubino
# Out:
#          yr_bp    co2_ppmv         year years_before_present
# 6       -51.03  367.999993      2001.03                 26.5
# 7       -51.03  368.044983      2001.03                 28.5
# 8          -48  361.780737         1998                 30.6
# 9   -46.279272  359.619747  1996.279272                 33.2
# 10  -46.279272  359.674988  1996.279272                 39.3
# ..         ...         ...          ...                  ...
# 393        NaN         NaN          NaN                  NaN
# 394        NaN         NaN          NaN                  NaN
# 395        NaN         NaN          NaN                  NaN
# 396        NaN         NaN          NaN                  NaN
# 397        NaN         NaN          NaN                  NaN
#
# [392 rows x 4 columns]
